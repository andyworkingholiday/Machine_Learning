# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import random

#X, Y 행렬을 난수로 생성
X = np.random.randn(10000, 100)
theta=np.random.randn(100,1)
Y = np.random.randn(10000,1)
#cost_theta=np.dot(x,theta)-y

def loss(theta):
    return np.linalg.norm(X.dot(theta)-y)^2
    
def grad(theta):
    return (X.T).dot(X.dot(theta)-y)
  # return X.T@(X@theta-y)

#경사 하강법 
def gradient_descent(X, Y, theta, iter):
   
    learning_rate = 0.005
    i=0
    while(i < iters):
        if (cost_function(new_theta1[0], new_theta2[0], y) < cost_function(theta1, theta2, y)):
            history_theta1.append(new_theta1[0])
            history_theta2.append(new_theta2[0])
            theta1 = new_theta1[0]
            theta2 = new_theta2[0]
            learning_rate *= 1.2
            i = i+1
           
        else:
            learning_rate *= 0.5
            print(i, "\t", "Calculating Learning late again")
            print(new_theta1[0], "\t", new_theta2[0])
            
        
    if (c==1):
        return history_theta1
    elif (c==2):
        return history_theta2

history1 = gradient_descent(2.8, -1.4, y, 30, 1)
history2 = gradient_descent(2.8, -1.4, y, 30, 2)
    
fig = plt.figure(figsize = (20,15))
ax = fig.gca(projection = '3d')
a = np.arange(-3, 3, 0.2)
b = np.arange(-3, 3, 0.2)
a, b = np.meshgrid(a, b)
outcome = cost_function(a, b, y)
surf = ax.plot_surface(a, b, outcome, rstride=1, cstride=1, alpha=0.3, linewidth=0, antialiased=False, cmap='rainbow')

a=np.array(history1)
b=np.array(history2)
outcome = cost_function(a, b, y)
ax.scatter(a, b, outcome, color="r");

print(outcome)
print("Final theta1 value is ", history1[30])
print("Final theta2 value is ", history2[30])

plt.xlabel('Theta1')
plt.ylabel('Theta2')

plt.show()
# Out:
# [16.06208248 15.91291112 15.73724927 15.53117496 15.29052157 15.01102195
#  14.68853761 14.31939731 13.90086804 13.43177345 12.91325523 12.34963668
#  11.74928954 11.12532431 10.49583112  9.883322    9.31302482  8.80983854
#   8.39415823  8.07741477  7.85884718  7.72526106  7.65474063  7.62333449
#   7.61163243  7.60787586  7.60678883  7.60652526  7.60648367  7.60648076
#   7.60648072]
# Final theta1 value is  0.3139127656299565
# Final theta2 value is  0.47043228760636957

# %%
plt.plot(outcome)

# %%
x= np.arange(-5.01, 5.01, 0.01)

theta=random.randint(2,4)
history=[theta]
learning_rate=0.01

for i in range(50):
    gradient=theta*2
    new_theta=theta-gradient*learning_rate
    if(abs(new_theta) < abs(theta)):
        learning_rate*=1.2
    history.append(new_theta)
    theta=new_theta
    print(theta)

    
his = np.array(history)

plt.plot(x,x**2)    
plt.plot(his, his**2, 'r--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2541ce1010bc> in <module>
# ----> 1 x= np.arange(-5.01, 5.01, 0.01)
#       2
#       3 theta=random.randint(2,4)
#       4 history=[theta]
#       5 learning_rate=0.01
#
# NameError: name 'np' is not defined

# %%
ㅁ
